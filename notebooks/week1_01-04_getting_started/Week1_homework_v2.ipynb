# %% [markdown]
# # NEUS 642 - Week 1 Homework

# %% [markdown]
# ## Background - for loops and iterables
#
# One thing we didn't cover in class that will be helpful for your homework is the **for loop**. For loops are very commonly used in programming languages to repeat the same operation across a sequence of data, so you might already be familiar with the concept.
#
# A classic for loop operates by incrementing an index and then using that index to guide an operation. In python, use `range` to specify the indexes to use. As with slicing, `range(0, n)` will iterate 0, 1, ... (n-1).  A single parameter implies starting at 0. I.e., `range(n)` is equivalent to `range(0, n)`.

# %%
animals = ['dog', 'cat', 'ferret']
for i in range(3):
    print("Item", i, ":", animals[i])

# %% [markdown]
# But, since Python is so cool, for loops work with any "iterable" object. For example, a list is an iterable:

# %%
for a in animals:
    print(a)

# %% [markdown]
# Even a string is an iterable!

# %%
for c in "MICKEY MOUSE":
    print(c)

# %% [markdown]
# An integer is **not** an iterable. Does the error message make sense?

# %%
x=10
for a in x:
    print(a)

# %% [markdown]
# Say you want both the list value and index? Use `enumerate`!

# %%
for i, a in enumerate(animals):
    print("Item", i, ":", a)

# %% [markdown]
# # Question 1 - String processing
#
# Write a function that counts how many vowels are in a string. Assume y is always a vowel. Rember that vowels can be upper or lower case.
#
# Example execution:
# ```
# [ ]: count_vowels("The quick brown fox jumped over the lazy dog.")
#
# 13
# ```

# %%
def count_vowels(s):
    # Your answer here

    return n

# %% [markdown]
# Test it:

# %%
count_vowels("The quick brown fox jumped over the lazy dog.")

# %%
count_vowels("Q: What's an undead neuroscientist's favorite food? A: bRAAAAINzzz!")

# %% [markdown]
# # Question 2 - Get started with statistics!
#
# Next week, we'll learn about `numpy`, which streamlines a lot of numerical processing. In the meantime, let's try some basics. Write a function that takes a `list` of numbers and returns the mean and standard deviation. Rember the definitions ($m$=mean, $s$=standard dev, $x(i)$ are the numbers in your list):
#
# $m = \frac{1}{n}\sum_i^n{x(i)}$
#
# $s = \sqrt{\frac{1}{n}\sum_i^n{(x(i) - m)^2}}$
#
# Example execution:
# ```
# [ ]: m, s = calculate_mean_std([1, 2, 3, 4, 5])
#
# [ ]: print(m, s)
#
# 3.0 1.4142135623730951
# ```
#
# Bonus: Use a pythonic for-loop that doesn't require a variable `i` to index into the list `x`

# %%
# Your answer here

# %% [markdown]
# Test it:

# %%
calculate_mean_std([1, 2, 3, 4, 5])

# %% [markdown]
# Scroll down for hints....
# ```
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ```

# %% [markdown]
# Hint 1: Use the `math` library to compute the square root.

# %%
import math
math.sqrt(2)

# %% [markdown]
# Hint 2: To use a `math` function inside your own function, just import it before you define the function.

# %%
import math
def pythag(a,b):
    c = math.sqrt(a**2 + b**2)
    return c

pythag(4,3)
